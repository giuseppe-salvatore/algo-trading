# %%
from market_data_provider.polygon import PolygonDataProvider

polygon = PolygonDataProvider()

symbols = polygon.get_supported_symbols("cs")
symbols
# Out:
# Total count 605 fetching 13 pages
# Fetching page 1/13 result page = 1
# {'CS': 50}
# Fetching page 2/13 result page = 2
# {'CS': 100}
# Fetching page 3/13 result page = 3
# {'CS': 150}
# Fetching page 4/13 result page = 4
# {'CS': 200}
# Fetching page 5/13 result page = 5
# {'CS': 250}
# Fetching page 6/13 result page = 6
# {'CS': 300}
# Fetching page 7/13 result page = 7
# {'CS': 350}
# Fetching page 8/13 result page = 8
# {'CS': 400}
# Fetching page 9/13 result page = 9
# {'CS': 450}
# Fetching page 10/13 result page = 10
# {'CS': 500}
# Fetching page 11/13 result page = 11
# {'CS': 550}
# Fetching page 12/13 result page = 12
# {'CS': 600}
# Fetching page 13/13 result page = 13
# {'CS': 605}
# [{'ticker': 'A',
#   'name': 'Agilent Technologies Inc.',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'type': 'CS',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NYE',
#   'updated': '2020-09-27',
#   'codes': {'cik': '0001090872',
#    'figiuid': 'EQ0087231700001000',
# ...
